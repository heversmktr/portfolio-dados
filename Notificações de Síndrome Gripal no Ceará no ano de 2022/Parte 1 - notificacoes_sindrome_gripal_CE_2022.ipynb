# %% [markdown]
# ## Analisando dados de Notificações de Síndrome Gripal no estado do Ceará no ano de 2022
#
# ## Parte 1 - Tratamento dos dados.

# %% [markdown]
# Devido à pandemia do Covid-19 o Ministério da Saúde, por meio da Vigilância em Saúde e Ambiente, implementou um sistema para registrar notificações de casos leves e moderados de suspeita de Covid-19.

# %% [markdown]
# ### Sobre os dados

# %% [markdown]
# Os dados são oriundos do sistema e-SUS Notifica, e contém como variáveis dados referentes ao estado, município de residência do paciente, resultados de exames laboratoriais, dados demográficos, além de outras informações originadas de análises clínicas.
#
# No entanto, existem estados e municípios que utilizam sistemas e métodos próprios para registro de notificações de suspeita de covid-19, e ainda estão em processo de integração com o e-SUS, por essa razão ainda pode haver alguma discrepância até a finalização do processo de integração.
#
# Os dados utilizados são referentes ao ano de 2022
#
# Para mais informações consulte: https://dados.gov.br/dados/conjuntos-dados/notificacoes-de-sindrome-gripal-leve-2022 [NÃO FUNCIONA ]
#
# DADOS DE 2023:
#
# 29/01/2024: https://opendatasus.saude.gov.br/dataset/notificacoes-de-sindrome-gripal-leve-2023
#
# * 24/01/2024: Por alguma razão o dataset está indisponível para download na plataforma dados.gov.br. O dataset utilizado nessa análise será disponibilizado em breve em outro local.
# * 29/01/2024: Adicionado um novo link contendo os datasets de 2023

# %% [markdown]
# ## Objetivo

# %% [markdown]
# O objetivo desse trabalho é realizar uma análise exploratória dos dados, tendo como foco o estado do Ceará, e depois algumas regiões e municípios. Nessa primeira etapa será realizada o tratamento dos dados, por se tratar de um dataset grande, é preciso ter atenção quanto ao consumo de memória, analisar os tipos de dados pode dar a chance de efetuar operações para convertê-los em formatos que ocupem menos espaço na memória, também servindo para deixar o conjunto de dados mais eficiente para outras operações. Outro motivo é o fato que o dataset contém dados vindos de múltiplas fontes, algumas inconsistências podem existir, e isso será comentado em outra parte.

# %% [markdown]
# ### Mãos à obra!

# %%
# Bibliotecas recomendadas

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import display

# %%
df1 = pd.read_csv('datasets/sus2022_CE.c000.csv', sep=';', low_memory = False)
df2 = pd.read_csv('datasets/sus2022_CE.c001.csv', sep=';', low_memory = False)
df3 = pd.read_csv('datasets/sus2022_CE.c002.csv', sep=';', low_memory = False)
df4 = pd.read_csv('datasets/sus2022_CE.c003.csv', sep=';', low_memory = False)

# %% [markdown]
# ### Primeira vista dos dados:

# %%
display(df1.head(), df2.head(), df3.head(), df4.head())
# Out:
#                                             sintomas profissionalSaude  \
# 0                                      Febre, Coriza               Não
# 1  Coriza, Distúrbios Olfativos, Distúrbios Gusta...               Sim
# 2                             Tosse, Febre, Dispneia               Não
# 3                               Tosse, Dor de Cabeça               Não
# 4                              Coriza, Dor de Cabeça               Não
#
#   racaCor outrosSintomas outrasCondicoes profissionalSeguranca  \
# 0   Parda            NaN             NaN                   Não
# 1   Parda        MIALGIA             NaN                   Não
# 2   Parda            NaN             NaN                   Não
# 3   Parda            NaN             NaN                   Não
# 4   Parda            NaN             NaN                   Não
#
#                           cbo condicoes       sexo estado  ...  \
# 0                         NaN       NaN   Feminino  Ceará  ...
# 1  2235 - Enfermeiros e afins       NaN   Feminino  Ceará  ...
# 2                         NaN       NaN   Feminino  Ceará  ...
# 3                         NaN       NaN   Feminino  Ceará  ...
# 4                         NaN       NaN  Masculino  Ceará  ...
#
#   codigoResultadoTeste3 codigoEstadoTeste4 codigoTipoTeste4  \
# 0                   NaN                NaN              NaN
# 1                   NaN                NaN              NaN
# 2                   NaN                NaN              NaN
# 3                   NaN                NaN              NaN
# 4                   NaN                NaN              NaN
#
#   codigoFabricanteTeste4 codigoResultadoTeste4 dataColetaTeste1  \
# 0                    NaN                   NaN              NaN
# 1                    NaN                   NaN       2022-01-24
# 2                    NaN                   NaN       2022-08-16
# 3                    NaN                   NaN       2022-01-31
# 4                    NaN                   NaN       2022-07-06
#
#    dataColetaTeste2 dataColetaTeste3 dataColetaTeste4  idade
# 0               NaN              NaN              NaN    NaN
# 1               NaN              NaN              NaN   31.0
# 2               NaN              NaN              NaN   25.0
# 3               NaN              NaN              NaN   23.0
# 4               NaN              NaN              NaN    NaN
#
# [5 rows x 64 columns]
#                          sintomas profissionalSaude   racaCor outrosSintomas  \
# 0                   Assintomático               Não     Parda            NaN
# 1   Tosse, Febre, Dor de Garganta               Não     Parda            NaN
# 2                 Dor de Garganta               Não    Branca            NaN
# 3                   Assintomático               Não  Ignorado            NaN
# 4  Febre, Dor de Garganta, Coriza               Não     Parda            NaN
#
#   outrasCondicoes profissionalSeguranca  \
# 0             NaN                   Não
# 1             NaN                   Não
# 2             NaN                   Não
# 3             NaN                   Não
# 4             NaN                   Não
#
#                                         cbo condicoes       sexo estado  ...  \
# 0                                       NaN  Gestante   Feminino  Ceará  ...
# 1                                       NaN       NaN   Feminino  Ceará  ...
# 2  5199 - Outros trabalhadores dos serviços       NaN   Feminino  Ceará  ...
# 3                                       NaN       NaN  Masculino  Ceará  ...
# 4                                       NaN       NaN   Feminino  Ceará  ...
#
#   codigoResultadoTeste3 codigoEstadoTeste4 codigoTipoTeste4  \
# 0                   NaN                NaN              NaN
# 1                   NaN                NaN              NaN
# 2                   NaN                NaN              NaN
# 3                   NaN                NaN              NaN
# 4                   NaN                NaN              NaN
#
#   codigoFabricanteTeste4 codigoResultadoTeste4 dataColetaTeste1  \
# 0                    NaN                   NaN              NaN
# 1                    NaN                   NaN       2022-07-04
# 2                    NaN                   NaN       2022-01-22
# 3                    NaN                   NaN       2022-02-07
# 4                    NaN                   NaN       2022-02-18
#
#    dataColetaTeste2 dataColetaTeste3 dataColetaTeste4  idade
# 0               NaN              NaN              NaN   35.0
# 1               NaN              NaN              NaN   36.0
# 2               NaN              NaN              NaN    NaN
# 3               NaN              NaN              NaN   19.0
# 4               NaN              NaN              NaN   38.0
#
# [5 rows x 64 columns]
#                                             sintomas profissionalSaude  \
# 0                                    Dor de Garganta               Não
# 1  Dor de Cabeça, Tosse, Dispneia, Dor de Gargant...               Não
# 2  Coriza, Febre, Dispneia, Dor de Garganta, Dist...               Não
# 3                                      Assintomático               Não
# 4                      Febre, Dor de Garganta, Tosse               Não
#
#     racaCor outrosSintomas outrasCondicoes profissionalSeguranca  \
# 0  Ignorado            NaN             NaN                   Não
# 1     Parda            NaN             NaN                   Não
# 2   Amarela            NaN             NaN                   Não
# 3     Parda            NaN             NaN                   Não
# 4     Parda            NaN             NaN                   Não
#
#                     cbo condicoes       sexo estado  ...  \
# 0  2234 - Farmacêuticos       NaN  Masculino  Ceará  ...
# 1                   NaN       NaN   Feminino  Ceará  ...
# 2                   NaN       NaN   Feminino  Ceará  ...
# 3                   NaN       NaN   Feminino  Ceará  ...
# 4                   NaN       NaN  Masculino  Ceará  ...
#
#   codigoResultadoTeste3 codigoEstadoTeste4 codigoTipoTeste4  \
# 0                   NaN                NaN              NaN
# 1                   NaN                NaN              NaN
# 2                   NaN                NaN              NaN
# 3                   NaN                NaN              NaN
# 4                   NaN                NaN              NaN
#
#   codigoFabricanteTeste4 codigoResultadoTeste4 dataColetaTeste1  \
# 0                    NaN                   NaN       2022-01-22
# 1                    NaN                   NaN       2022-01-10
# 2                    NaN                   NaN       2022-02-04
# 3                    NaN                   NaN       2022-01-12
# 4                    NaN                   NaN       2022-03-18
#
#    dataColetaTeste2 dataColetaTeste3 dataColetaTeste4  idade
# 0               NaN              NaN              NaN   42.0
# 1               NaN              NaN              NaN    NaN
# 2               NaN              NaN              NaN   20.0
# 3               NaN              NaN              NaN   14.0
# 4               NaN              NaN              NaN   12.0
#
# [5 rows x 64 columns]
#                                             sintomas profissionalSaude  \
# 0              Tosse, Febre, Dor de Garganta, Coriza               Não
# 1                     Coriza, Febre, Dor de Garganta               Não
# 2                Coriza, Dor de Cabeça, Tosse, Febre               Não
# 3                               Tosse, Febre, Coriza               Não
# 4  Coriza, Distúrbios Olfativos, Distúrbios Gusta...               Não
#
#   racaCor outrosSintomas outrasCondicoes profissionalSeguranca  cbo condicoes  \
# 0  Branca            NaN             NaN                   Não  NaN       NaN
# 1   Parda            NaN             NaN                   Não  NaN       NaN
# 2   Parda            NaN             NaN                   Não  NaN       NaN
# 3   Parda            NaN             NaN                   Não  NaN       NaN
# 4   Parda            NaN             NaN                   Não  NaN       NaN
#
#         sexo estado  ... codigoResultadoTeste3 codigoEstadoTeste4  \
# 0   Feminino  Ceará  ...                   NaN                NaN
# 1  Masculino  Ceará  ...                   NaN                NaN
# 2   Feminino  Ceará  ...                   NaN                NaN
# 3  Masculino  Ceará  ...                   NaN                NaN
# 4   Feminino  Ceará  ...                   NaN                NaN
#
#   codigoTipoTeste4 codigoFabricanteTeste4 codigoResultadoTeste4  \
# 0              NaN                    NaN                   NaN
# 1              NaN                    NaN                   NaN
# 2              NaN                    NaN                   NaN
# 3              NaN                    NaN                   NaN
# 4              NaN                    NaN                   NaN
#
#   dataColetaTeste1  dataColetaTeste2 dataColetaTeste3 dataColetaTeste4  idade
# 0       2022-07-08        2022-07-04              NaN              NaN   21.0
# 1       2022-01-19               NaN              NaN              NaN    NaN
# 2       2022-01-11        2022-01-11              NaN              NaN    NaN
# 3       2022-07-19               NaN              NaN              NaN   39.0
# 4       2022-02-06               NaN              NaN              NaN   28.0
#
# [5 rows x 64 columns]

# %% [markdown]
# Observando o número de variáveis (colunas) em cada dataset, nada impede que os quatro conjuntos de dados possam ser concatenados. Ciente de que a concatenação dos dados na forma como estão irá gerar um único arquivo, o qual será maior e consumirá mais memória ainda no estado atual em que se encontram. Por essa razão, deixarei a etapa de criação de um único arquivo para quando os dados estiverem otimizados.

# %% [markdown]
# ### Verificando o consumo de memória

# %%
# Verifica o consumo de memória de cada dataset

df1.info(memory_usage = 'deep')
df2.info(memory_usage = 'deep')
df3.info(memory_usage = 'deep')
df4.info(memory_usage = 'deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545305 entries, 0 to 545304
# Data columns (total 64 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   sintomas                           545303 non-null  object
#  1   profissionalSaude                  545303 non-null  object
#  2   racaCor                            545208 non-null  object
#  3   outrosSintomas                     75288 non-null   object
#  4   outrasCondicoes                    15084 non-null   object
#  5   profissionalSeguranca              544777 non-null  object
#  6   cbo                                25663 non-null   object
#  7   condicoes                          52509 non-null   object
#  8   sexo                               545305 non-null  object
#  9   estado                             545305 non-null  object
#  10  estadoIBGE                         537454 non-null  object
#  11  municipio                          545304 non-null  object
#  12  municipioIBGE                      537403 non-null  object
#  13  origem                             545305 non-null  object
#  14  estadoNotificacao                  545305 non-null  object
#  15  municipioNotificacao               543702 non-null  object
#  16  municipioNotificacaoIBGE           523040 non-null  float64
#  17  evolucaoCaso                       279012 non-null  object
#  18  classificacaoFinal                 284126 non-null  object
#  19  codigoEstrategiaCovid              528563 non-null  float64
#  20  codigoBuscaAtivaAssintomatico      29645 non-null   float64
#  21  outroBuscaAtivaAssintomatico       8783 non-null    object
#  22  codigoTriagemPopulacaoEspecifica   8751 non-null    float64
#  23  outroTriagemPopulacaoEspecifica    4666 non-null    object
#  24  codigoLocalRealizacaoTestagem      528555 non-null  float64
#  25  outroLocalRealizacaoTestagem       30791 non-null   object
#  26  codigoRecebeuVacina                454460 non-null  object
#  27  codigoLaboratorioPrimeiraDose      338151 non-null  object
#  28  codigoLaboratorioSegundaDose       308858 non-null  object
#  29  lotePrimeiraDose                   338135 non-null  object
#  30  loteSegundaDose                    308839 non-null  object
#  31  codigoContemComunidadeTradicional  538571 non-null  object
#  32  source_id                          545305 non-null  object
#  33  excluido                           545305 non-null  object
#  34  validado                           545305 non-null  object
#  35  codigoDosesVacina                  366100 non-null  object
#  36  estadoNotificacaoIBGE              524644 non-null  object
#  37  totalTestesRealizados              545305 non-null  object
#  38  dataNotificacao                    532694 non-null  object
#  39  dataInicioSintomas                 446666 non-null  object
#  40  dataEncerramento                   264091 non-null  object
#  41  dataPrimeiraDose                   310712 non-null  object
#  42  dataSegundaDose                    295662 non-null  object
#  43  codigoEstadoTeste1                 484076 non-null  float64
#  44  codigoTipoTeste1                   484076 non-null  float64
#  45  codigoFabricanteTeste1             330210 non-null  float64
#  46  codigoResultadoTeste1              406430 non-null  float64
#  47  codigoEstadoTeste2                 41459 non-null   float64
#  48  codigoTipoTeste2                   41459 non-null   float64
#  49  codigoFabricanteTeste2             14264 non-null   float64
#  50  codigoResultadoTeste2              30810 non-null   float64
#  51  codigoEstadoTeste3                 5763 non-null    float64
#  52  codigoTipoTeste3                   5763 non-null    float64
#  53  codigoFabricanteTeste3             1967 non-null    float64
#  54  codigoResultadoTeste3              4465 non-null    float64
#  55  codigoEstadoTeste4                 1351 non-null    float64
#  56  codigoTipoTeste4                   1351 non-null    float64
#  57  codigoFabricanteTeste4             562 non-null     float64
#  58  codigoResultadoTeste4              1210 non-null    float64
#  59  dataColetaTeste1                   445550 non-null  object
#  60  dataColetaTeste2                   34624 non-null   object
#  61  dataColetaTeste3                   4773 non-null    object
#  62  dataColetaTeste4                   1253 non-null    object
#  63  idade                              418203 non-null  float64
# dtypes: float64(22), object(42)
# memory usage: 1.3 GB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305776 entries, 0 to 305775
# Data columns (total 64 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   sintomas                           305776 non-null  object
#  1   profissionalSaude                  305776 non-null  object
#  2   racaCor                            305711 non-null  object
#  3   outrosSintomas                     42227 non-null   object
#  4   outrasCondicoes                    7992 non-null    object
#  5   profissionalSeguranca              305521 non-null  object
#  6   cbo                                13882 non-null   object
#  7   condicoes                          27781 non-null   object
#  8   sexo                               305776 non-null  object
#  9   estado                             305776 non-null  object
#  10  estadoIBGE                         300977 non-null  object
#  11  municipio                          305776 non-null  object
#  12  municipioIBGE                      300941 non-null  object
#  13  origem                             305776 non-null  object
#  14  estadoNotificacao                  305776 non-null  object
#  15  municipioNotificacao               304881 non-null  object
#  16  municipioNotificacaoIBGE           291836 non-null  float64
#  17  evolucaoCaso                       158163 non-null  object
#  18  classificacaoFinal                 162461 non-null  object
#  19  codigoEstrategiaCovid              295498 non-null  float64
#  20  codigoBuscaAtivaAssintomatico      19492 non-null   float64
#  21  outroBuscaAtivaAssintomatico       4468 non-null    object
#  22  codigoTriagemPopulacaoEspecifica   6152 non-null    float64
#  23  outroTriagemPopulacaoEspecifica    3485 non-null    object
#  24  codigoLocalRealizacaoTestagem      295487 non-null  float64
#  25  outroLocalRealizacaoTestagem       24459 non-null   object
#  26  codigoRecebeuVacina                277027 non-null  float64
#  27  codigoLaboratorioPrimeiraDose      198099 non-null  object
#  28  codigoLaboratorioSegundaDose       182282 non-null  object
#  29  lotePrimeiraDose                   198102 non-null  object
#  30  loteSegundaDose                    182284 non-null  object
#  31  codigoContemComunidadeTradicional  301947 non-null  float64
#  32  source_id                          305776 non-null  object
#  33  excluido                           305776 non-null  bool
#  34  validado                           305776 non-null  bool
#  35  codigoDosesVacina                  214777 non-null  object
#  36  estadoNotificacaoIBGE              292731 non-null  object
#  37  totalTestesRealizados              305776 non-null  int64
#  38  dataNotificacao                    305766 non-null  object
#  39  dataInicioSintomas                 251264 non-null  object
#  40  dataEncerramento                   154802 non-null  object
#  41  dataPrimeiraDose                   184804 non-null  object
#  42  dataSegundaDose                    178060 non-null  object
#  43  codigoEstadoTeste1                 276245 non-null  float64
#  44  codigoTipoTeste1                   276244 non-null  float64
#  45  codigoFabricanteTeste1             189146 non-null  float64
#  46  codigoResultadoTeste1              238769 non-null  float64
#  47  codigoEstadoTeste2                 22220 non-null   float64
#  48  codigoTipoTeste2                   22220 non-null   float64
#  49  codigoFabricanteTeste2             6514 non-null    float64
#  50  codigoResultadoTeste2              16965 non-null   float64
#  51  codigoEstadoTeste3                 2143 non-null    float64
#  52  codigoTipoTeste3                   2143 non-null    float64
#  53  codigoFabricanteTeste3             494 non-null     float64
#  54  codigoResultadoTeste3              1568 non-null    float64
#  55  codigoEstadoTeste4                 411 non-null     float64
#  56  codigoTipoTeste4                   411 non-null     float64
#  57  codigoFabricanteTeste4             106 non-null     float64
#  58  codigoResultadoTeste4              349 non-null     float64
#  59  dataColetaTeste1                   258185 non-null  object
#  60  dataColetaTeste2                   18936 non-null   object
#  61  dataColetaTeste3                   1657 non-null    object
#  62  dataColetaTeste4                   352 non-null     object
#  63  idade                              241453 non-null  float64
# dtypes: bool(2), float64(24), int64(1), object(37)
# memory usage: 666.3 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152086 entries, 0 to 152085
# Data columns (total 64 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   sintomas                           152086 non-null  object
#  1   profissionalSaude                  152086 non-null  object
#  2   racaCor                            152048 non-null  object
#  3   outrosSintomas                     20642 non-null   object
#  4   outrasCondicoes                    4056 non-null    object
#  5   profissionalSeguranca              151943 non-null  object
#  6   cbo                                6963 non-null    object
#  7   condicoes                          13972 non-null   object
#  8   sexo                               152086 non-null  object
#  9   estado                             152086 non-null  object
#  10  estadoIBGE                         149705 non-null  object
#  11  municipio                          152086 non-null  object
#  12  municipioIBGE                      149674 non-null  object
#  13  origem                             152086 non-null  object
#  14  estadoNotificacao                  152086 non-null  object
#  15  municipioNotificacao               151690 non-null  object
#  16  municipioNotificacaoIBGE           145369 non-null  float64
#  17  evolucaoCaso                       78267 non-null   object
#  18  classificacaoFinal                 80522 non-null   object
#  19  codigoEstrategiaCovid              147084 non-null  float64
#  20  codigoBuscaAtivaAssintomatico      9870 non-null    float64
#  21  outroBuscaAtivaAssintomatico       2225 non-null    object
#  22  codigoTriagemPopulacaoEspecifica   3002 non-null    float64
#  23  outroTriagemPopulacaoEspecifica    1692 non-null    object
#  24  codigoLocalRealizacaoTestagem      147080 non-null  float64
#  25  outroLocalRealizacaoTestagem       12256 non-null   object
#  26  codigoRecebeuVacina                137654 non-null  float64
#  27  codigoLaboratorioPrimeiraDose      98665 non-null   object
#  28  codigoLaboratorioSegundaDose       90694 non-null   object
#  29  lotePrimeiraDose                   98665 non-null   object
#  30  loteSegundaDose                    90696 non-null   object
#  31  codigoContemComunidadeTradicional  150257 non-null  float64
#  32  source_id                          152086 non-null  object
#  33  excluido                           152086 non-null  bool
#  34  validado                           152086 non-null  bool
#  35  codigoDosesVacina                  106895 non-null  object
#  36  estadoNotificacaoIBGE              145765 non-null  object
#  37  totalTestesRealizados              152086 non-null  int64
#  38  dataNotificacao                    152084 non-null  object
#  39  dataInicioSintomas                 124729 non-null  object
#  40  dataEncerramento                   76653 non-null   object
#  41  dataPrimeiraDose                   92091 non-null   object
#  42  dataSegundaDose                    88637 non-null   object
#  43  codigoEstadoTeste1                 137481 non-null  float64
#  44  codigoTipoTeste1                   137480 non-null  float64
#  45  codigoFabricanteTeste1             94398 non-null   float64
#  46  codigoResultadoTeste1              118973 non-null  float64
#  47  codigoEstadoTeste2                 10907 non-null   float64
#  48  codigoTipoTeste2                   10907 non-null   float64
#  49  codigoFabricanteTeste2             3204 non-null    float64
#  50  codigoResultadoTeste2              8322 non-null    float64
#  51  codigoEstadoTeste3                 1028 non-null    float64
#  52  codigoTipoTeste3                   1028 non-null    float64
#  53  codigoFabricanteTeste3             247 non-null     float64
#  54  codigoResultadoTeste3              765 non-null     float64
#  55  codigoEstadoTeste4                 211 non-null     float64
#  56  codigoTipoTeste4                   211 non-null     float64
#  57  codigoFabricanteTeste4             45 non-null      float64
#  58  codigoResultadoTeste4              172 non-null     float64
#  59  dataColetaTeste1                   128544 non-null  object
#  60  dataColetaTeste2                   9311 non-null    object
#  61  dataColetaTeste3                   798 non-null     object
#  62  dataColetaTeste4                   176 non-null     object
#  63  idade                              119953 non-null  float64
# dtypes: bool(2), float64(24), int64(1), object(37)
# memory usage: 331.4 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306712 entries, 0 to 306711
# Data columns (total 64 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   sintomas                           306712 non-null  object
#  1   profissionalSaude                  306711 non-null  object
#  2   racaCor                            306661 non-null  object
#  3   outrosSintomas                     42008 non-null   object
#  4   outrasCondicoes                    7966 non-null    object
#  5   profissionalSeguranca              306473 non-null  object
#  6   cbo                                14171 non-null   object
#  7   condicoes                          27429 non-null   object
#  8   sexo                               306712 non-null  object
#  9   estado                             306712 non-null  object
#  10  estadoIBGE                         301920 non-null  object
#  11  municipio                          306712 non-null  object
#  12  municipioIBGE                      301865 non-null  object
#  13  origem                             306712 non-null  object
#  14  estadoNotificacao                  306712 non-null  object
#  15  municipioNotificacao               305903 non-null  object
#  16  municipioNotificacaoIBGE           293040 non-null  float64
#  17  evolucaoCaso                       158328 non-null  object
#  18  classificacaoFinal                 162589 non-null  object
#  19  codigoEstrategiaCovid              296635 non-null  float64
#  20  codigoBuscaAtivaAssintomatico      19518 non-null   float64
#  21  outroBuscaAtivaAssintomatico       4323 non-null    object
#  22  codigoTriagemPopulacaoEspecifica   6274 non-null    float64
#  23  outroTriagemPopulacaoEspecifica    3616 non-null    object
#  24  codigoLocalRealizacaoTestagem      296630 non-null  float64
#  25  outroLocalRealizacaoTestagem       24528 non-null   object
#  26  codigoRecebeuVacina                277964 non-null  float64
#  27  codigoLaboratorioPrimeiraDose      198500 non-null  object
#  28  codigoLaboratorioSegundaDose       182679 non-null  object
#  29  lotePrimeiraDose                   198503 non-null  object
#  30  loteSegundaDose                    182679 non-null  object
#  31  codigoContemComunidadeTradicional  302937 non-null  float64
#  32  source_id                          306712 non-null  object
#  33  excluido                           306712 non-null  bool
#  34  validado                           306712 non-null  bool
#  35  codigoDosesVacina                  215430 non-null  object
#  36  estadoNotificacaoIBGE              293849 non-null  object
#  37  totalTestesRealizados              306712 non-null  int64
#  38  dataNotificacao                    306701 non-null  object
#  39  dataInicioSintomas                 252094 non-null  object
#  40  dataEncerramento                   154930 non-null  object
#  41  dataPrimeiraDose                   185231 non-null  object
#  42  dataSegundaDose                    178436 non-null  object
#  43  codigoEstadoTeste1                 277260 non-null  float64
#  44  codigoTipoTeste1                   277259 non-null  float64
#  45  codigoFabricanteTeste1             190175 non-null  float64
#  46  codigoResultadoTeste1              239637 non-null  float64
#  47  codigoEstadoTeste2                 22191 non-null   float64
#  48  codigoTipoTeste2                   22191 non-null   float64
#  49  codigoFabricanteTeste2             6548 non-null    float64
#  50  codigoResultadoTeste2              16914 non-null   float64
#  51  codigoEstadoTeste3                 2173 non-null    float64
#  52  codigoTipoTeste3                   2173 non-null    float64
#  53  codigoFabricanteTeste3             560 non-null     float64
#  54  codigoResultadoTeste3              1613 non-null    float64
#  55  codigoEstadoTeste4                 427 non-null     float64
#  56  codigoTipoTeste4                   427 non-null     float64
#  57  codigoFabricanteTeste4             102 non-null     float64
#  58  codigoResultadoTeste4              355 non-null     float64
#  59  dataColetaTeste1                   259132 non-null  object
#  60  dataColetaTeste2                   18872 non-null   object
#  61  dataColetaTeste3                   1693 non-null    object
#  62  dataColetaTeste4                   361 non-null     object
#  63  idade                              242301 non-null  float64
# dtypes: bool(2), float64(24), int64(1), object(37)
# memory usage: 668.1 MB

# %% [markdown]
# Observa-se que os tipos de dados (dtype) predominantes são __float64__, e __object__:
#
# Mas antes é preciso verificar de fato quais dados estão inseridos nesses formatos. Uma forma de realizar essa tarefa é capturando todas as colunas do dataset que contém dados armazenados em __float64__ e __object__, e mostrar quais os valores mínimo e máximo armazenados.

# %%
# Captura todas as colunas onde o tipo de dado predominante for float64

df1_float64_columns = [col for col in df1 if df1[col].dtype == 'float64' ]
df2_float64_columns = [col for col in df2 if df2[col].dtype == 'float64' ]
df3_float64_columns = [col for col in df3 if df3[col].dtype == 'float64' ]
df4_float64_columns = [col for col in df4 if df4[col].dtype == 'float64' ]

# Exibe os valores máximos e mínimo de cada coluna float64: 
for column in df1_float64_columns:
    print('df1', column, df1[column].min(), df1[column].max())

for column in df2_float64_columns:
    print('df2', column, df2[column].min(), df2[column].max())

for column in df3_float64_columns:
    print('df3', column, df3[column].min(), df3[column].max())

for column in df4_float64_columns:
    print('df4', column, df4[column].min(), df4[column].max())
# Out:
# df1 municipioNotificacaoIBGE 1400282.0 4201901.0
# df1 codigoEstrategiaCovid 1.0 3.0
# df1 codigoBuscaAtivaAssintomatico 1.0 4.0
# df1 codigoTriagemPopulacaoEspecifica 1.0 5.0
# df1 codigoLocalRealizacaoTestagem 1.0 7.0
# df1 codigoEstadoTeste1 1.0 4.0
# df1 codigoTipoTeste1 1.0 9.0
# df1 codigoFabricanteTeste1 1.0 1363.0
# df1 codigoResultadoTeste1 1.0 3.0
# df1 codigoEstadoTeste2 1.0 4.0
# df1 codigoTipoTeste2 1.0 9.0
# df1 codigoFabricanteTeste2 1.0 1363.0
# df1 codigoResultadoTeste2 1.0 3.0
# df1 codigoEstadoTeste3 1.0 4.0
# df1 codigoTipoTeste3 1.0 9.0
# df1 codigoFabricanteTeste3 1.0 1363.0
# df1 codigoResultadoTeste3 1.0 3.0
# df1 codigoEstadoTeste4 1.0 4.0
# df1 codigoTipoTeste4 1.0 8.0
# df1 codigoFabricanteTeste4 1.0 915.0
# df1 codigoResultadoTeste4 1.0 3.0
# df1 idade 0.0 182.0
# df2 municipioNotificacaoIBGE 1400282.0 4201901.0
# df2 codigoEstrategiaCovid 1.0 3.0
# df2 codigoBuscaAtivaAssintomatico 1.0 4.0
# df2 codigoTriagemPopulacaoEspecifica 1.0 5.0
# df2 codigoLocalRealizacaoTestagem 1.0 7.0
# df2 codigoRecebeuVacina 1.0 3.0
# df2 codigoContemComunidadeTradicional 1.0 2.0
# df2 codigoEstadoTeste1 1.0 4.0
# df2 codigoTipoTeste1 1.0 9.0
# df2 codigoFabricanteTeste1 1.0 1363.0
# df2 codigoResultadoTeste1 1.0 3.0
# df2 codigoEstadoTeste2 1.0 4.0
# df2 codigoTipoTeste2 1.0 9.0
# df2 codigoFabricanteTeste2 1.0 1363.0
# df2 codigoResultadoTeste2 1.0 3.0
# df2 codigoEstadoTeste3 1.0 4.0
# df2 codigoTipoTeste3 1.0 9.0
# df2 codigoFabricanteTeste3 1.0 915.0
# df2 codigoResultadoTeste3 1.0 3.0
# df2 codigoEstadoTeste4 1.0 4.0
# df2 codigoTipoTeste4 1.0 9.0
# df2 codigoFabricanteTeste4 60.0 11347.0
# df2 codigoResultadoTeste4 1.0 2.0
# df2 idade 0.0 137.0
# df3 municipioNotificacaoIBGE 1400282.0 5005004.0
# df3 codigoEstrategiaCovid 1.0 3.0
# df3 codigoBuscaAtivaAssintomatico 1.0 4.0
# df3 codigoTriagemPopulacaoEspecifica 1.0 5.0
# df3 codigoLocalRealizacaoTestagem 1.0 7.0
# df3 codigoRecebeuVacina 1.0 3.0
# df3 codigoContemComunidadeTradicional 1.0 2.0
# df3 codigoEstadoTeste1 1.0 4.0
# df3 codigoTipoTeste1 1.0 9.0
# df3 codigoFabricanteTeste1 1.0 1363.0
# df3 codigoResultadoTeste1 1.0 3.0
# df3 codigoEstadoTeste2 1.0 4.0
# df3 codigoTipoTeste2 1.0 9.0
# df3 codigoFabricanteTeste2 1.0 915.0
# df3 codigoResultadoTeste2 1.0 3.0
# df3 codigoEstadoTeste3 1.0 4.0
# df3 codigoTipoTeste3 1.0 9.0
# df3 codigoFabricanteTeste3 1.0 915.0
# df3 codigoResultadoTeste3 1.0 2.0
# df3 codigoEstadoTeste4 1.0 4.0
# df3 codigoTipoTeste4 1.0 7.0
# df3 codigoFabricanteTeste4 53.0 915.0
# df3 codigoResultadoTeste4 1.0 2.0
# df3 idade 0.0 106.0
# df4 municipioNotificacaoIBGE 1400282.0 5005004.0
# df4 codigoEstrategiaCovid 1.0 3.0
# df4 codigoBuscaAtivaAssintomatico 1.0 4.0
# df4 codigoTriagemPopulacaoEspecifica 1.0 5.0
# df4 codigoLocalRealizacaoTestagem 1.0 7.0
# df4 codigoRecebeuVacina 1.0 3.0
# df4 codigoContemComunidadeTradicional 1.0 2.0
# df4 codigoEstadoTeste1 1.0 4.0
# df4 codigoTipoTeste1 1.0 9.0
# df4 codigoFabricanteTeste1 1.0 1363.0
# df4 codigoResultadoTeste1 1.0 3.0
# df4 codigoEstadoTeste2 1.0 4.0
# df4 codigoTipoTeste2 1.0 9.0
# df4 codigoFabricanteTeste2 1.0 1363.0
# df4 codigoResultadoTeste2 1.0 3.0
# df4 codigoEstadoTeste3 1.0 4.0
# df4 codigoTipoTeste3 1.0 9.0
# df4 codigoFabricanteTeste3 1.0 1363.0
# df4 codigoResultadoTeste3 1.0 3.0
# df4 codigoEstadoTeste4 1.0 3.0
# df4 codigoTipoTeste4 1.0 9.0
# df4 codigoFabricanteTeste4 1.0 915.0
# df4 codigoResultadoTeste4 1.0 2.0
# df4 idade 0.0 150.0

# %%
# Colunas com dados em float64 em todos os datasets

# Aproveitando que são as mesmas variáveis salvei uma lista com elas.

colunas_float64 = list(df1.select_dtypes(include=['float64']).columns)
print(colunas_float64)

colunas = ['municipioNotificacaoIBGE', 'codigoEstrategiaCovid', 'codigoBuscaAtivaAssintomatico',
           'codigoTriagemPopulacaoEspecifica', 'codigoLocalRealizacaoTestagem', 'codigoEstadoTeste1', 
           'codigoTipoTeste1', 'codigoFabricanteTeste1', 'codigoResultadoTeste1', 'codigoEstadoTeste2', 
           'codigoTipoTeste2', 'codigoFabricanteTeste2', 'codigoResultadoTeste2', 'codigoEstadoTeste3', 
           'codigoTipoTeste3', 'codigoFabricanteTeste3', 'codigoResultadoTeste3', 'codigoEstadoTeste4', 
           'codigoTipoTeste4', 'codigoFabricanteTeste4', 'codigoResultadoTeste4', 'idade']
# Out:
# ['municipioNotificacaoIBGE', 'codigoEstrategiaCovid', 'codigoBuscaAtivaAssintomatico', 'codigoTriagemPopulacaoEspecifica', 'codigoLocalRealizacaoTestagem', 'codigoEstadoTeste1', 'codigoTipoTeste1', 'codigoFabricanteTeste1', 'codigoResultadoTeste1', 'codigoEstadoTeste2', 'codigoTipoTeste2', 'codigoFabricanteTeste2', 'codigoResultadoTeste2', 'codigoEstadoTeste3', 'codigoTipoTeste3', 'codigoFabricanteTeste3', 'codigoResultadoTeste3', 'codigoEstadoTeste4', 'codigoTipoTeste4', 'codigoFabricanteTeste4', 'codigoResultadoTeste4', 'idade']

# %% [markdown]
# Analisando as colunas com dados em __float64__ vemos que aparentemente os dados salvos podem ser convertidos em algum formato do tipo __int__ (inteiro). Mas antes de prosseguir iremos confirmar se não existe nenhum valor com casa decimal diferente de 0. A célula com o código abaixo pode ser usada para testar todos os dataframes, já que os mesmos compartilham as mesmas colunas.

# %%
# Função para verificar se um número tem casas decimais diferentes de zero

def verifica_decimais(numero):
    parte_decimal = str(numero).split(".")[1] if "." in str(numero) else ""
    return any(digito != "0" for digito in parte_decimal)

# Função para contar a quantidade de valores com casas decimais diferentes de zero
def contar_casas_decimais_diferentes_de_zero(coluna):
    return coluna.apply(verifica_decimais).sum()

# Lista de colunas às quais a função será aplicada
colunas_a_verificar = colunas

# Use map para aplicar a função a cada elemento do DataFrame
df1_casas_decimais = df1[colunas_a_verificar].map(verifica_decimais)
df2_casas_decimais = df2[colunas_a_verificar].map(verifica_decimais)
df3_casas_decimais = df3[colunas_a_verificar].map(verifica_decimais)
df4_casas_decimais = df4[colunas_a_verificar].map(verifica_decimais)

# Use a função contar_casas_decimais_diferentes_de_zero para contar a quantidade em cada coluna
df1_quantidade_casas_decimais = df1[colunas_a_verificar].apply(contar_casas_decimais_diferentes_de_zero)
df2_quantidade_casas_decimais = df2[colunas_a_verificar].apply(contar_casas_decimais_diferentes_de_zero)
df3_quantidade_casas_decimais = df3[colunas_a_verificar].apply(contar_casas_decimais_diferentes_de_zero)
df4_quantidade_casas_decimais = df4[colunas_a_verificar].apply(contar_casas_decimais_diferentes_de_zero)

# Exiba o resultado
print(f" Dataframe 1 \n {df1_quantidade_casas_decimais}")
print(f" Dataframe 2 \n {df2_quantidade_casas_decimais}")
print(f" Dataframe 3 \n {df3_quantidade_casas_decimais}")
print(f" Dataframe 4 \n {df4_quantidade_casas_decimais}")

# Essa célula pode ser utilizada para testar os demais datasets
# Out:
#  Dataframe 1
#  municipioNotificacaoIBGE            0
# codigoEstrategiaCovid               0
# codigoBuscaAtivaAssintomatico       0
# codigoTriagemPopulacaoEspecifica    0
# codigoLocalRealizacaoTestagem       0
# codigoEstadoTeste1                  0
# codigoTipoTeste1                    0
# codigoFabricanteTeste1              0
# codigoResultadoTeste1               0
# codigoEstadoTeste2                  0
# codigoTipoTeste2                    0
# codigoFabricanteTeste2              0
# codigoResultadoTeste2               0
# codigoEstadoTeste3                  0
# codigoTipoTeste3                    0
# codigoFabricanteTeste3              0
# codigoResultadoTeste3               0
# codigoEstadoTeste4                  0
# codigoTipoTeste4                    0
# codigoFabricanteTeste4              0
# codigoResultadoTeste4               0
# idade                               0
# dtype: int64
#  Dataframe 2
#  municipioNotificacaoIBGE            0
# codigoEstrategiaCovid               0
# codigoBuscaAtivaAssintomatico       0
# codigoTriagemPopulacaoEspecifica    0
# codigoLocalRealizacaoTestagem       0
# codigoEstadoTeste1                  0
# codigoTipoTeste1                    0
# codigoFabricanteTeste1              0
# codigoResultadoTeste1               0
# codigoEstadoTeste2                  0
# codigoTipoTeste2                    0
# codigoFabricanteTeste2              0
# codigoResultadoTeste2               0
# codigoEstadoTeste3                  0
# codigoTipoTeste3                    0
# codigoFabricanteTeste3              0
# codigoResultadoTeste3               0
# codigoEstadoTeste4                  0
# codigoTipoTeste4                    0
# codigoFabricanteTeste4              0
# codigoResultadoTeste4               0
# idade                               0
# dtype: int64
#  Dataframe 3
#  municipioNotificacaoIBGE            0
# codigoEstrategiaCovid               0
# codigoBuscaAtivaAssintomatico       0
# codigoTriagemPopulacaoEspecifica    0
# codigoLocalRealizacaoTestagem       0
# codigoEstadoTeste1                  0
# codigoTipoTeste1                    0
# codigoFabricanteTeste1              0
# codigoResultadoTeste1               0
# codigoEstadoTeste2                  0
# codigoTipoTeste2                    0
# codigoFabricanteTeste2              0
# codigoResultadoTeste2               0
# codigoEstadoTeste3                  0
# codigoTipoTeste3                    0
# codigoFabricanteTeste3              0
# codigoResultadoTeste3               0
# codigoEstadoTeste4                  0
# codigoTipoTeste4                    0
# codigoFabricanteTeste4              0
# codigoResultadoTeste4               0
# idade                               0
# dtype: int64
#  Dataframe 4
#  municipioNotificacaoIBGE            0
# codigoEstrategiaCovid               0
# codigoBuscaAtivaAssintomatico       0
# codigoTriagemPopulacaoEspecifica    0
# codigoLocalRealizacaoTestagem       0
# codigoEstadoTeste1                  0
# codigoTipoTeste1                    0
# codigoFabricanteTeste1              0
# codigoResultadoTeste1               0
# codigoEstadoTeste2                  0
# codigoTipoTeste2                    0
# codigoFabricanteTeste2              0
# codigoResultadoTeste2               0
# codigoEstadoTeste3                  0
# codigoTipoTeste3                    0
# codigoFabricanteTeste3              0
# codigoResultadoTeste3               0
# codigoEstadoTeste4                  0
# codigoTipoTeste4                    0
# codigoFabricanteTeste4              0
# codigoResultadoTeste4               0
# idade                               0
# dtype: int64

# %% [markdown]
# ### Sobre os valores NaN
#
# Valores __NaN__ (Not a Number) podem indicar a ausência de dados, revelando que determinadas informações não foram registradas. Na nossa análise, optamos por manter esses valores __NaN__, pois representam um tipo de informação que pode ser significativa e não foi preenchida. Antes de prosseguirmos com qualquer análise adicional, realizaremos a contagem desses valores __NaN__ para compreender sua extensão e considerar as estratégias apropriadas de manipulação.

# %%
# Verificando quantos NaN existem em cada dataset

for column in df1_float64_columns:
    print('df1', column, df1[column].isna().sum())

for column in df2_float64_columns:
    print('df2', column, df2[column].isna().sum())

for column in df3_float64_columns:
    print('df3', column, df3[column].isna().sum())

for column in df4_float64_columns:
    print('df4', column, df4[column].isna().sum())
# Out:
# df1 municipioNotificacaoIBGE 22265
# df1 codigoEstrategiaCovid 16742
# df1 codigoBuscaAtivaAssintomatico 515660
# df1 codigoTriagemPopulacaoEspecifica 536554
# df1 codigoLocalRealizacaoTestagem 16750
# df1 codigoEstadoTeste1 61229
# df1 codigoTipoTeste1 61229
# df1 codigoFabricanteTeste1 215095
# df1 codigoResultadoTeste1 138875
# df1 codigoEstadoTeste2 503846
# df1 codigoTipoTeste2 503846
# df1 codigoFabricanteTeste2 531041
# df1 codigoResultadoTeste2 514495
# df1 codigoEstadoTeste3 539542
# df1 codigoTipoTeste3 539542
# df1 codigoFabricanteTeste3 543338
# df1 codigoResultadoTeste3 540840
# df1 codigoEstadoTeste4 543954
# df1 codigoTipoTeste4 543954
# df1 codigoFabricanteTeste4 544743
# df1 codigoResultadoTeste4 544095
# df1 idade 127102
# df2 municipioNotificacaoIBGE 13940
# df2 codigoEstrategiaCovid 10278
# df2 codigoBuscaAtivaAssintomatico 286284
# df2 codigoTriagemPopulacaoEspecifica 299624
# df2 codigoLocalRealizacaoTestagem 10289
# df2 codigoRecebeuVacina 28749
# df2 codigoContemComunidadeTradicional 3829
# df2 codigoEstadoTeste1 29531
# df2 codigoTipoTeste1 29532
# df2 codigoFabricanteTeste1 116630
# df2 codigoResultadoTeste1 67007
# df2 codigoEstadoTeste2 283556
# df2 codigoTipoTeste2 283556
# df2 codigoFabricanteTeste2 299262
# df2 codigoResultadoTeste2 288811
# df2 codigoEstadoTeste3 303633
# df2 codigoTipoTeste3 303633
# df2 codigoFabricanteTeste3 305282
# df2 codigoResultadoTeste3 304208
# df2 codigoEstadoTeste4 305365
# df2 codigoTipoTeste4 305365
# df2 codigoFabricanteTeste4 305670
# df2 codigoResultadoTeste4 305427
# df2 idade 64323
# df3 municipioNotificacaoIBGE 6717
# df3 codigoEstrategiaCovid 5002
# df3 codigoBuscaAtivaAssintomatico 142216
# df3 codigoTriagemPopulacaoEspecifica 149084
# df3 codigoLocalRealizacaoTestagem 5006
# df3 codigoRecebeuVacina 14432
# df3 codigoContemComunidadeTradicional 1829
# df3 codigoEstadoTeste1 14605
# df3 codigoTipoTeste1 14606
# df3 codigoFabricanteTeste1 57688
# df3 codigoResultadoTeste1 33113
# df3 codigoEstadoTeste2 141179
# df3 codigoTipoTeste2 141179
# df3 codigoFabricanteTeste2 148882
# df3 codigoResultadoTeste2 143764
# df3 codigoEstadoTeste3 151058
# df3 codigoTipoTeste3 151058
# df3 codigoFabricanteTeste3 151839
# df3 codigoResultadoTeste3 151321
# df3 codigoEstadoTeste4 151875
# df3 codigoTipoTeste4 151875
# df3 codigoFabricanteTeste4 152041
# df3 codigoResultadoTeste4 151914
# df3 idade 32133
# df4 municipioNotificacaoIBGE 13672
# df4 codigoEstrategiaCovid 10077
# df4 codigoBuscaAtivaAssintomatico 287194
# df4 codigoTriagemPopulacaoEspecifica 300438
# df4 codigoLocalRealizacaoTestagem 10082
# df4 codigoRecebeuVacina 28748
# df4 codigoContemComunidadeTradicional 3775
# df4 codigoEstadoTeste1 29452
# df4 codigoTipoTeste1 29453
# df4 codigoFabricanteTeste1 116537
# df4 codigoResultadoTeste1 67075
# df4 codigoEstadoTeste2 284521
# df4 codigoTipoTeste2 284521
# df4 codigoFabricanteTeste2 300164
# df4 codigoResultadoTeste2 289798
# df4 codigoEstadoTeste3 304539
# df4 codigoTipoTeste3 304539
# df4 codigoFabricanteTeste3 306152
# df4 codigoResultadoTeste3 305099
# df4 codigoEstadoTeste4 306285
# df4 codigoTipoTeste4 306285
# df4 codigoFabricanteTeste4 306610
# df4 codigoResultadoTeste4 306357
# df4 idade 64411

# %% [markdown]
# ### Downcasting
#
# Verificado e confirmado que não há necessidade de manter os dados no formato __float64__, será realizado o __downcasting__; ou seja, iremos converter os dados para um formato que ocupa menos espaço na memória. De acordo com a análise feita, converter para __unsigned_int__ é mais vantajoso.

# %%
# Downcasting (float64 to unint)

colunas_float64_list = ['municipioNotificacaoIBGE', 'codigoEstrategiaCovid', 
                        'codigoBuscaAtivaAssintomatico', 'codigoTriagemPopulacaoEspecifica', 
                        'codigoLocalRealizacaoTestagem', 'codigoEstadoTeste1', 'codigoTipoTeste1', 
                        'codigoFabricanteTeste1', 'codigoResultadoTeste1', 'codigoEstadoTeste2', 
                        'codigoTipoTeste2', 'codigoFabricanteTeste2', 'codigoResultadoTeste2', 
                        'codigoEstadoTeste3', 'codigoTipoTeste3', 'codigoFabricanteTeste3', 'codigoResultadoTeste3', 
                        'codigoEstadoTeste4', 'codigoTipoTeste4', 'codigoFabricanteTeste4', 'codigoResultadoTeste4', 
                        'idade']

df1[colunas_float64_list] = df1[colunas_float64_list].apply(pd.to_numeric, downcast='unsigned', errors='coerce').astype('Int64')
df2[colunas_float64_list] = df2[colunas_float64_list].apply(pd.to_numeric, downcast='unsigned', errors='coerce').astype('Int64')
df3[colunas_float64_list] = df3[colunas_float64_list].apply(pd.to_numeric, downcast='unsigned', errors='coerce').astype('Int64')
df4[colunas_float64_list] = df4[colunas_float64_list].apply(pd.to_numeric, downcast='unsigned', errors='coerce').astype('Int64')

# %% [markdown]
# Provando que os dados realmente foram convertidos.

# %%
# Checando o dtype

df1.info(memory_usage  = 'deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545305 entries, 0 to 545304
# Data columns (total 64 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   sintomas                           545303 non-null  object
#  1   profissionalSaude                  545303 non-null  object
#  2   racaCor                            545208 non-null  object
#  3   outrosSintomas                     75288 non-null   object
#  4   outrasCondicoes                    15084 non-null   object
#  5   profissionalSeguranca              544777 non-null  object
#  6   cbo                                25663 non-null   object
#  7   condicoes                          52509 non-null   object
#  8   sexo                               545305 non-null  object
#  9   estado                             545305 non-null  object
#  10  estadoIBGE                         537454 non-null  object
#  11  municipio                          545304 non-null  object
#  12  municipioIBGE                      537403 non-null  object
#  13  origem                             545305 non-null  object
#  14  estadoNotificacao                  545305 non-null  object
#  15  municipioNotificacao               543702 non-null  object
#  16  municipioNotificacaoIBGE           523040 non-null  Int64
#  17  evolucaoCaso                       279012 non-null  object
#  18  classificacaoFinal                 284126 non-null  object
#  19  codigoEstrategiaCovid              528563 non-null  Int64
#  20  codigoBuscaAtivaAssintomatico      29645 non-null   Int64
#  21  outroBuscaAtivaAssintomatico       8783 non-null    object
#  22  codigoTriagemPopulacaoEspecifica   8751 non-null    Int64
#  23  outroTriagemPopulacaoEspecifica    4666 non-null    object
#  24  codigoLocalRealizacaoTestagem      528555 non-null  Int64
#  25  outroLocalRealizacaoTestagem       30791 non-null   object
#  26  codigoRecebeuVacina                454460 non-null  object
#  27  codigoLaboratorioPrimeiraDose      338151 non-null  object
#  28  codigoLaboratorioSegundaDose       308858 non-null  object
#  29  lotePrimeiraDose                   338135 non-null  object
#  30  loteSegundaDose                    308839 non-null  object
#  31  codigoContemComunidadeTradicional  538571 non-null  object
#  32  source_id                          545305 non-null  object
#  33  excluido                           545305 non-null  object
#  34  validado                           545305 non-null  object
#  35  codigoDosesVacina                  366100 non-null  object
#  36  estadoNotificacaoIBGE              524644 non-null  object
#  37  totalTestesRealizados              545305 non-null  object
#  38  dataNotificacao                    532694 non-null  object
#  39  dataInicioSintomas                 446666 non-null  object
#  40  dataEncerramento                   264091 non-null  object
#  41  dataPrimeiraDose                   310712 non-null  object
#  42  dataSegundaDose                    295662 non-null  object
#  43  codigoEstadoTeste1                 484076 non-null  Int64
#  44  codigoTipoTeste1                   484076 non-null  Int64
#  45  codigoFabricanteTeste1             330210 non-null  Int64
#  46  codigoResultadoTeste1              406430 non-null  Int64
#  47  codigoEstadoTeste2                 41459 non-null   Int64
#  48  codigoTipoTeste2                   41459 non-null   Int64
#  49  codigoFabricanteTeste2             14264 non-null   Int64
#  50  codigoResultadoTeste2              30810 non-null   Int64
#  51  codigoEstadoTeste3                 5763 non-null    Int64
#  52  codigoTipoTeste3                   5763 non-null    Int64
#  53  codigoFabricanteTeste3             1967 non-null    Int64
#  54  codigoResultadoTeste3              4465 non-null    Int64
#  55  codigoEstadoTeste4                 1351 non-null    Int64
#  56  codigoTipoTeste4                   1351 non-null    Int64
#  57  codigoFabricanteTeste4             562 non-null     Int64
#  58  codigoResultadoTeste4              1210 non-null    Int64
#  59  dataColetaTeste1                   445550 non-null  object
#  60  dataColetaTeste2                   34624 non-null   object
#  61  dataColetaTeste3                   4773 non-null    object
#  62  dataColetaTeste4                   1253 non-null    object
#  63  idade                              418203 non-null  Int64
# dtypes: Int64(22), object(42)
# memory usage: 1.3 GB

# %% [markdown]
# Exibindo os valores de mínimo e máximo novamente para simples conferência:

# %% [markdown]
# # Usando como exemplo o Dataset 1:
# # Exibindo os valores de máximo e mínimo novamente para simples conferência:
# for column in df1[colunas_float64_list]:
#    print(column, df1[column].min(), df1[column].max())

# %% [markdown]
# Mesmo após o __downcast__, não foi obtida uma redução significativa do uso de memória. Nos datasets nota-se a predominância do tipo de dado __object__, que nesse caso está sendo utilizado para armazenar strings. Nos próximos passos será feita a análise das colunas onde estão contidos os dados do tipo __object__ e analisada a possibilidade de serem convertidos para __category__.

# %% [markdown]
# ### Conversão de object para categorycal
#
# Explicando um pouco sobre o que é pretendido alcançar nessa etapa. Nos datasets temos variáveis que são preenchidas apenas por strings e estão registradas como tipo __object__. Em python o tipo __object__ é um tipo especial de dado que faz referências a outros tipos, como no arquivo .CSV não existe informações sobre os tipos de dados que ele carrega, então o pandas carrega tudo como tipo __object__ já que não consegue prever qual o tipo de dado.
# Nos datasets existem vários dados __object__ que são strings, e essas strings se repetem muitas vezes, poder resumir elas a somente um tipo de informação é melhor que repetir a mesma informação sempre. Por exemplo, imagine um conjunto de dados onde eu tenho uma variável que serve para armazenar um dos três tipos de respostas disponíveis para uma pergunta feita em uma pesquisa: 1 - Sim, 2 - Não, 3 - Prefiro não opinar. Agora, suponha que esses dados foram salvos em um arquivo .CSV e possuem mais de 10.000 linhas respondidas. Quando carregados no Pandas, cada espaço contendo uma das três strings possíveis irá ocupar uma quantidade de memória referente ao tamanho de cada string. Agora quando forem convertidas para __category__ ao invés de gastar espaço repetindo a mesma string, o pandas irá armazenar o valor como categórico, fazendo somente uma referência ao endereço onde está armazenado o valor daquela variável, ao invés de repetir-la.

# %% [markdown]
# Sabendo disso vamos procurar em quais colunas predominam os dados do tipo object e mostrar a quantidade de valores únicos que cada uma dessas colunas possuem.

# %%
# Analisando as colunas do tipo object

# Capturando as colunas com dtype == object em cada dataframe. 
df1_object_columns = [col for col in df1.columns if df1[col].dtype == 'object']
df2_object_columns = [col for col in df2.columns if df2[col].dtype == 'object']
df3_object_columns = [col for col in df3.columns if df3[col].dtype == 'object']
df4_object_columns = [col for col in df4.columns if df4[col].dtype == 'object']

# Imprime a quantidade de valores únicos de cada coluna

for column in df1_object_columns:
    print('df1', column, df1[column].nunique())

for column in df2_object_columns:
    print('df2', column, df2[column].nunique())

for column in df3_object_columns:
    print('df3', column, df3[column].nunique())

for column in df4_object_columns:
    print('df4', column, df4[column].nunique())
# Out:
# df1 sintomas 3046
# df1 profissionalSaude 2
# df1 racaCor 6
# df1 outrosSintomas 19125
# df1 outrasCondicoes 3935
# df1 profissionalSeguranca 3
# df1 cbo 394
# df1 condicoes 297
# df1 sexo 5
# df1 estado 29
# df1 estadoIBGE 29
# df1 municipio 1194
# df1 municipioIBGE 1220
# df1 origem 5
# df1 estadoNotificacao 3
# df1 municipioNotificacao 184
# df1 evolucaoCaso 8
# df1 classificacaoFinal 7
# df1 outroBuscaAtivaAssintomatico 1562
# df1 outroTriagemPopulacaoEspecifica 662
# df1 outroLocalRealizacaoTestagem 1323
# df1 codigoRecebeuVacina 5
# df1 codigoLaboratorioPrimeiraDose 36
# df1 codigoLaboratorioSegundaDose 32
# df1 lotePrimeiraDose 977
# df1 loteSegundaDose 961
# df1 codigoContemComunidadeTradicional 4
# df1 source_id 545304
# df1 excluido 2
# df1 validado 3
# df1 codigoDosesVacina 23
# df1 estadoNotificacaoIBGE 3
# df1 totalTestesRealizados 14
# df1 dataNotificacao 1137
# df1 dataInicioSintomas 1131
# df1 dataEncerramento 1278
# df1 dataPrimeiraDose 637
# df1 dataSegundaDose 652
# df1 dataColetaTeste1 1297
# df1 dataColetaTeste2 1072
# df1 dataColetaTeste3 810
# df1 dataColetaTeste4 454
# df2 sintomas 2504
# df2 profissionalSaude 2
# df2 racaCor 6
# df2 outrosSintomas 10396
# df2 outrasCondicoes 1983
# df2 profissionalSeguranca 2
# df2 cbo 347
# df2 condicoes 234
# df2 sexo 3
# df2 estado 27
# df2 estadoIBGE 27
# df2 municipio 761
# df2 municipioIBGE 768
# df2 origem 2
# df2 estadoNotificacao 1
# df2 municipioNotificacao 183
# df2 evolucaoCaso 7
# df2 classificacaoFinal 6
# df2 outroBuscaAtivaAssintomatico 1016
# df2 outroTriagemPopulacaoEspecifica 475
# df2 outroLocalRealizacaoTestagem 1047
# df2 codigoLaboratorioPrimeiraDose 39
# df2 codigoLaboratorioSegundaDose 29
# df2 lotePrimeiraDose 847
# df2 loteSegundaDose 811
# df2 source_id 305776
# df2 codigoDosesVacina 15
# df2 estadoNotificacaoIBGE 1
# df2 dataNotificacao 939
# df2 dataInicioSintomas 996
# df2 dataEncerramento 930
# df2 dataPrimeiraDose 549
# df2 dataSegundaDose 561
# df2 dataColetaTeste1 971
# df2 dataColetaTeste2 873
# df2 dataColetaTeste3 550
# df2 dataColetaTeste4 216
# df3 sintomas 1958
# df3 profissionalSaude 2
# df3 racaCor 6
# df3 outrosSintomas 5713
# df3 outrasCondicoes 1193
# df3 profissionalSeguranca 2
# df3 cbo 281
# df3 condicoes 164
# df3 sexo 3
# df3 estado 27
# df3 estadoIBGE 27
# df3 municipio 551
# df3 municipioIBGE 551
# df3 origem 2
# df3 estadoNotificacao 1
# df3 municipioNotificacao 182
# df3 evolucaoCaso 7
# df3 classificacaoFinal 6
# df3 outroBuscaAtivaAssintomatico 637
# df3 outroTriagemPopulacaoEspecifica 273
# df3 outroLocalRealizacaoTestagem 729
# df3 codigoLaboratorioPrimeiraDose 33
# df3 codigoLaboratorioSegundaDose 30
# df3 lotePrimeiraDose 702
# df3 loteSegundaDose 660
# df3 source_id 152086
# df3 codigoDosesVacina 15
# df3 estadoNotificacaoIBGE 1
# df3 dataNotificacao 902
# df3 dataInicioSintomas 964
# df3 dataEncerramento 874
# df3 dataPrimeiraDose 522
# df3 dataSegundaDose 526
# df3 dataColetaTeste1 929
# df3 dataColetaTeste2 796
# df3 dataColetaTeste3 369
# df3 dataColetaTeste4 141
# df4 sintomas 2479
# df4 profissionalSaude 2
# df4 racaCor 6
# df4 outrosSintomas 10432
# df4 outrasCondicoes 1991
# df4 profissionalSeguranca 2
# df4 cbo 364
# df4 condicoes 223
# df4 sexo 3
# df4 estado 27
# df4 estadoIBGE 27
# df4 municipio 781
# df4 municipioIBGE 792
# df4 origem 2
# df4 estadoNotificacao 1
# df4 municipioNotificacao 183
# df4 evolucaoCaso 7
# df4 classificacaoFinal 6
# df4 outroBuscaAtivaAssintomatico 1037
# df4 outroTriagemPopulacaoEspecifica 489
# df4 outroLocalRealizacaoTestagem 1011
# df4 codigoLaboratorioPrimeiraDose 39
# df4 codigoLaboratorioSegundaDose 35
# df4 lotePrimeiraDose 862
# df4 loteSegundaDose 807
# df4 source_id 306712
# df4 codigoDosesVacina 15
# df4 estadoNotificacaoIBGE 1
# df4 dataNotificacao 937
# df4 dataInicioSintomas 994
# df4 dataEncerramento 928
# df4 dataPrimeiraDose 552
# df4 dataSegundaDose 553
# df4 dataColetaTeste1 959
# df4 dataColetaTeste2 882
# df4 dataColetaTeste3 529
# df4 dataColetaTeste4 220

# %% [markdown]
# Informações como estado, município, e alguns códigos se repetem bastante.

# %%
# Converte de object para category

for column in df1_object_columns:
    df1[column] = df1[column].astype('category')# Anlaysing the memory usage of the dataframe after converting object to category

for column in df2_object_columns:
    df2[column] = df2[column].astype('category')# Anlaysing the memory usage of the dataframe after converting object to category

for column in df3_object_columns:
    df3[column] = df3[column].astype('category')# Anlaysing the memory usage of the dataframe after converting object to category

for column in df4_object_columns:
    df4[column] = df4[column].astype('category')# Anlaysing the memory usage of the dataframe after converting object to category

# Checa o uso da memória

df1.info(memory_usage='deep')
df2.info(memory_usage='deep')
df3.info(memory_usage='deep')
df4.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545305 entries, 0 to 545304
# Data columns (total 64 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   sintomas                           545303 non-null  category
#  1   profissionalSaude                  545303 non-null  category
#  2   racaCor                            545208 non-null  category
#  3   outrosSintomas                     75288 non-null   category
#  4   outrasCondicoes                    15084 non-null   category
#  5   profissionalSeguranca              544777 non-null  category
#  6   cbo                                25663 non-null   category
#  7   condicoes                          52509 non-null   category
#  8   sexo                               545305 non-null  category
#  9   estado                             545305 non-null  category
#  10  estadoIBGE                         537454 non-null  category
#  11  municipio                          545304 non-null  category
#  12  municipioIBGE                      537403 non-null  category
#  13  origem                             545305 non-null  category
#  14  estadoNotificacao                  545305 non-null  category
#  15  municipioNotificacao               543702 non-null  category
#  16  municipioNotificacaoIBGE           523040 non-null  Int64
#  17  evolucaoCaso                       279012 non-null  category
#  18  classificacaoFinal                 284126 non-null  category
#  19  codigoEstrategiaCovid              528563 non-null  Int64
#  20  codigoBuscaAtivaAssintomatico      29645 non-null   Int64
#  21  outroBuscaAtivaAssintomatico       8783 non-null    category
#  22  codigoTriagemPopulacaoEspecifica   8751 non-null    Int64
#  23  outroTriagemPopulacaoEspecifica    4666 non-null    category
#  24  codigoLocalRealizacaoTestagem      528555 non-null  Int64
#  25  outroLocalRealizacaoTestagem       30791 non-null   category
#  26  codigoRecebeuVacina                454460 non-null  category
#  27  codigoLaboratorioPrimeiraDose      338151 non-null  category
#  28  codigoLaboratorioSegundaDose       308858 non-null  category
#  29  lotePrimeiraDose                   338135 non-null  category
#  30  loteSegundaDose                    308839 non-null  category
#  31  codigoContemComunidadeTradicional  538571 non-null  category
#  32  source_id                          545305 non-null  category
#  33  excluido                           545305 non-null  category
#  34  validado                           545305 non-null  category
#  35  codigoDosesVacina                  366100 non-null  category
#  36  estadoNotificacaoIBGE              524644 non-null  category
#  37  totalTestesRealizados              545305 non-null  category
#  38  dataNotificacao                    532694 non-null  category
#  39  dataInicioSintomas                 446666 non-null  category
#  40  dataEncerramento                   264091 non-null  category
#  41  dataPrimeiraDose                   310712 non-null  category
#  42  dataSegundaDose                    295662 non-null  category
#  43  codigoEstadoTeste1                 484076 non-null  Int64
#  44  codigoTipoTeste1                   484076 non-null  Int64
#  45  codigoFabricanteTeste1             330210 non-null  Int64
#  46  codigoResultadoTeste1              406430 non-null  Int64
#  47  codigoEstadoTeste2                 41459 non-null   Int64
#  48  codigoTipoTeste2                   41459 non-null   Int64
#  49  codigoFabricanteTeste2             14264 non-null   Int64
#  50  codigoResultadoTeste2              30810 non-null   Int64
#  51  codigoEstadoTeste3                 5763 non-null    Int64
#  52  codigoTipoTeste3                   5763 non-null    Int64
#  53  codigoFabricanteTeste3             1967 non-null    Int64
#  54  codigoResultadoTeste3              4465 non-null    Int64
#  55  codigoEstadoTeste4                 1351 non-null    Int64
#  56  codigoTipoTeste4                   1351 non-null    Int64
#  57  codigoFabricanteTeste4             562 non-null     Int64
#  58  codigoResultadoTeste4              1210 non-null    Int64
#  59  dataColetaTeste1                   445550 non-null  category
#  60  dataColetaTeste2                   34624 non-null   category
#  61  dataColetaTeste3                   4773 non-null    category
#  62  dataColetaTeste4                   1253 non-null    category
#  63  idade                              418203 non-null  Int64
# dtypes: Int64(22), category(42)
# memory usage: 193.7 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305776 entries, 0 to 305775
# Data columns (total 64 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   sintomas                           305776 non-null  category
#  1   profissionalSaude                  305776 non-null  category
#  2   racaCor                            305711 non-null  category
#  3   outrosSintomas                     42227 non-null   category
#  4   outrasCondicoes                    7992 non-null    category
#  5   profissionalSeguranca              305521 non-null  category
#  6   cbo                                13882 non-null   category
#  7   condicoes                          27781 non-null   category
#  8   sexo                               305776 non-null  category
#  9   estado                             305776 non-null  category
#  10  estadoIBGE                         300977 non-null  category
#  11  municipio                          305776 non-null  category
#  12  municipioIBGE                      300941 non-null  category
#  13  origem                             305776 non-null  category
#  14  estadoNotificacao                  305776 non-null  category
#  15  municipioNotificacao               304881 non-null  category
#  16  municipioNotificacaoIBGE           291836 non-null  Int64
#  17  evolucaoCaso                       158163 non-null  category
#  18  classificacaoFinal                 162461 non-null  category
#  19  codigoEstrategiaCovid              295498 non-null  Int64
#  20  codigoBuscaAtivaAssintomatico      19492 non-null   Int64
#  21  outroBuscaAtivaAssintomatico       4468 non-null    category
#  22  codigoTriagemPopulacaoEspecifica   6152 non-null    Int64
#  23  outroTriagemPopulacaoEspecifica    3485 non-null    category
#  24  codigoLocalRealizacaoTestagem      295487 non-null  Int64
#  25  outroLocalRealizacaoTestagem       24459 non-null   category
#  26  codigoRecebeuVacina                277027 non-null  float64
#  27  codigoLaboratorioPrimeiraDose      198099 non-null  category
#  28  codigoLaboratorioSegundaDose       182282 non-null  category
#  29  lotePrimeiraDose                   198102 non-null  category
#  30  loteSegundaDose                    182284 non-null  category
#  31  codigoContemComunidadeTradicional  301947 non-null  float64
#  32  source_id                          305776 non-null  category
#  33  excluido                           305776 non-null  bool
#  34  validado                           305776 non-null  bool
#  35  codigoDosesVacina                  214777 non-null  category
#  36  estadoNotificacaoIBGE              292731 non-null  category
#  37  totalTestesRealizados              305776 non-null  int64
#  38  dataNotificacao                    305766 non-null  category
#  39  dataInicioSintomas                 251264 non-null  category
#  40  dataEncerramento                   154802 non-null  category
#  41  dataPrimeiraDose                   184804 non-null  category
#  42  dataSegundaDose                    178060 non-null  category
#  43  codigoEstadoTeste1                 276245 non-null  Int64
#  44  codigoTipoTeste1                   276244 non-null  Int64
#  45  codigoFabricanteTeste1             189146 non-null  Int64
#  46  codigoResultadoTeste1              238769 non-null  Int64
#  47  codigoEstadoTeste2                 22220 non-null   Int64
#  48  codigoTipoTeste2                   22220 non-null   Int64
#  49  codigoFabricanteTeste2             6514 non-null    Int64
#  50  codigoResultadoTeste2              16965 non-null   Int64
#  51  codigoEstadoTeste3                 2143 non-null    Int64
#  52  codigoTipoTeste3                   2143 non-null    Int64
#  53  codigoFabricanteTeste3             494 non-null     Int64
#  54  codigoResultadoTeste3              1568 non-null    Int64
#  55  codigoEstadoTeste4                 411 non-null     Int64
#  56  codigoTipoTeste4                   411 non-null     Int64
#  57  codigoFabricanteTeste4             106 non-null     Int64
#  58  codigoResultadoTeste4              349 non-null     Int64
#  59  dataColetaTeste1                   258185 non-null  category
#  60  dataColetaTeste2                   18936 non-null   category
#  61  dataColetaTeste3                   1657 non-null    category
#  62  dataColetaTeste4                   352 non-null     category
#  63  idade                              241453 non-null  Int64
# dtypes: Int64(22), bool(2), category(37), float64(2), int64(1)
# memory usage: 114.3 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152086 entries, 0 to 152085
# Data columns (total 64 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   sintomas                           152086 non-null  category
#  1   profissionalSaude                  152086 non-null  category
#  2   racaCor                            152048 non-null  category
#  3   outrosSintomas                     20642 non-null   category
#  4   outrasCondicoes                    4056 non-null    category
#  5   profissionalSeguranca              151943 non-null  category
#  6   cbo                                6963 non-null    category
#  7   condicoes                          13972 non-null   category
#  8   sexo                               152086 non-null  category
#  9   estado                             152086 non-null  category
#  10  estadoIBGE                         149705 non-null  category
#  11  municipio                          152086 non-null  category
#  12  municipioIBGE                      149674 non-null  category
#  13  origem                             152086 non-null  category
#  14  estadoNotificacao                  152086 non-null  category
#  15  municipioNotificacao               151690 non-null  category
#  16  municipioNotificacaoIBGE           145369 non-null  Int64
#  17  evolucaoCaso                       78267 non-null   category
#  18  classificacaoFinal                 80522 non-null   category
#  19  codigoEstrategiaCovid              147084 non-null  Int64
#  20  codigoBuscaAtivaAssintomatico      9870 non-null    Int64
#  21  outroBuscaAtivaAssintomatico       2225 non-null    category
#  22  codigoTriagemPopulacaoEspecifica   3002 non-null    Int64
#  23  outroTriagemPopulacaoEspecifica    1692 non-null    category
#  24  codigoLocalRealizacaoTestagem      147080 non-null  Int64
#  25  outroLocalRealizacaoTestagem       12256 non-null   category
#  26  codigoRecebeuVacina                137654 non-null  float64
#  27  codigoLaboratorioPrimeiraDose      98665 non-null   category
#  28  codigoLaboratorioSegundaDose       90694 non-null   category
#  29  lotePrimeiraDose                   98665 non-null   category
#  30  loteSegundaDose                    90696 non-null   category
#  31  codigoContemComunidadeTradicional  150257 non-null  float64
#  32  source_id                          152086 non-null  category
#  33  excluido                           152086 non-null  bool
#  34  validado                           152086 non-null  bool
#  35  codigoDosesVacina                  106895 non-null  category
#  36  estadoNotificacaoIBGE              145765 non-null  category
#  37  totalTestesRealizados              152086 non-null  int64
#  38  dataNotificacao                    152084 non-null  category
#  39  dataInicioSintomas                 124729 non-null  category
#  40  dataEncerramento                   76653 non-null   category
#  41  dataPrimeiraDose                   92091 non-null   category
#  42  dataSegundaDose                    88637 non-null   category
#  43  codigoEstadoTeste1                 137481 non-null  Int64
#  44  codigoTipoTeste1                   137480 non-null  Int64
#  45  codigoFabricanteTeste1             94398 non-null   Int64
#  46  codigoResultadoTeste1              118973 non-null  Int64
#  47  codigoEstadoTeste2                 10907 non-null   Int64
#  48  codigoTipoTeste2                   10907 non-null   Int64
#  49  codigoFabricanteTeste2             3204 non-null    Int64
#  50  codigoResultadoTeste2              8322 non-null    Int64
#  51  codigoEstadoTeste3                 1028 non-null    Int64
#  52  codigoTipoTeste3                   1028 non-null    Int64
#  53  codigoFabricanteTeste3             247 non-null     Int64
#  54  codigoResultadoTeste3              765 non-null     Int64
#  55  codigoEstadoTeste4                 211 non-null     Int64
#  56  codigoTipoTeste4                   211 non-null     Int64
#  57  codigoFabricanteTeste4             45 non-null      Int64
#  58  codigoResultadoTeste4              172 non-null     Int64
#  59  dataColetaTeste1                   128544 non-null  category
#  60  dataColetaTeste2                   9311 non-null    category
#  61  dataColetaTeste3                   798 non-null     category
#  62  dataColetaTeste4                   176 non-null     category
#  63  idade                              119953 non-null  Int64
# dtypes: Int64(22), bool(2), category(37), float64(2), int64(1)
# memory usage: 57.5 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306712 entries, 0 to 306711
# Data columns (total 64 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   sintomas                           306712 non-null  category
#  1   profissionalSaude                  306711 non-null  category
#  2   racaCor                            306661 non-null  category
#  3   outrosSintomas                     42008 non-null   category
#  4   outrasCondicoes                    7966 non-null    category
#  5   profissionalSeguranca              306473 non-null  category
#  6   cbo                                14171 non-null   category
#  7   condicoes                          27429 non-null   category
#  8   sexo                               306712 non-null  category
#  9   estado                             306712 non-null  category
#  10  estadoIBGE                         301920 non-null  category
#  11  municipio                          306712 non-null  category
#  12  municipioIBGE                      301865 non-null  category
#  13  origem                             306712 non-null  category
#  14  estadoNotificacao                  306712 non-null  category
#  15  municipioNotificacao               305903 non-null  category
#  16  municipioNotificacaoIBGE           293040 non-null  Int64
#  17  evolucaoCaso                       158328 non-null  category
#  18  classificacaoFinal                 162589 non-null  category
#  19  codigoEstrategiaCovid              296635 non-null  Int64
#  20  codigoBuscaAtivaAssintomatico      19518 non-null   Int64
#  21  outroBuscaAtivaAssintomatico       4323 non-null    category
#  22  codigoTriagemPopulacaoEspecifica   6274 non-null    Int64
#  23  outroTriagemPopulacaoEspecifica    3616 non-null    category
#  24  codigoLocalRealizacaoTestagem      296630 non-null  Int64
#  25  outroLocalRealizacaoTestagem       24528 non-null   category
#  26  codigoRecebeuVacina                277964 non-null  float64
#  27  codigoLaboratorioPrimeiraDose      198500 non-null  category
#  28  codigoLaboratorioSegundaDose       182679 non-null  category
#  29  lotePrimeiraDose                   198503 non-null  category
#  30  loteSegundaDose                    182679 non-null  category
#  31  codigoContemComunidadeTradicional  302937 non-null  float64
#  32  source_id                          306712 non-null  category
#  33  excluido                           306712 non-null  bool
#  34  validado                           306712 non-null  bool
#  35  codigoDosesVacina                  215430 non-null  category
#  36  estadoNotificacaoIBGE              293849 non-null  category
#  37  totalTestesRealizados              306712 non-null  int64
#  38  dataNotificacao                    306701 non-null  category
#  39  dataInicioSintomas                 252094 non-null  category
#  40  dataEncerramento                   154930 non-null  category
#  41  dataPrimeiraDose                   185231 non-null  category
#  42  dataSegundaDose                    178436 non-null  category
#  43  codigoEstadoTeste1                 277260 non-null  Int64
#  44  codigoTipoTeste1                   277259 non-null  Int64
#  45  codigoFabricanteTeste1             190175 non-null  Int64
#  46  codigoResultadoTeste1              239637 non-null  Int64
#  47  codigoEstadoTeste2                 22191 non-null   Int64
#  48  codigoTipoTeste2                   22191 non-null   Int64
#  49  codigoFabricanteTeste2             6548 non-null    Int64
#  50  codigoResultadoTeste2              16914 non-null   Int64
#  51  codigoEstadoTeste3                 2173 non-null    Int64
#  52  codigoTipoTeste3                   2173 non-null    Int64
#  53  codigoFabricanteTeste3             560 non-null     Int64
#  54  codigoResultadoTeste3              1613 non-null    Int64
#  55  codigoEstadoTeste4                 427 non-null     Int64
#  56  codigoTipoTeste4                   427 non-null     Int64
#  57  codigoFabricanteTeste4             102 non-null     Int64
#  58  codigoResultadoTeste4              355 non-null     Int64
#  59  dataColetaTeste1                   259132 non-null  category
#  60  dataColetaTeste2                   18872 non-null   category
#  61  dataColetaTeste3                   1693 non-null    category
#  62  dataColetaTeste4                   361 non-null     category
#  63  idade                              242301 non-null  Int64
# dtypes: Int64(22), bool(2), category(37), float64(2), int64(1)
# memory usage: 114.6 MB

# %% [markdown]
# Comparado com o que foi visto no início houve uma redução drástica no consumo de memória. Agora os dataframes consomem menor espaço de memória, o que os tornam mais eficientes. Antes de encerrerar irei discutir uma outra alternativa envolvendo um outro formato de arquivo, o __.parquet__.

# %% [markdown]
# ### Outra alternativa

# %% [markdown]
# Uma outra alternativa para lidar com grandes conjuntos de dados grande seria concatenar os arquivos em __.csv__ e em seguida convertê-los para __.parquet__, esse formato valoriza a compactação e eficiência de armazenamento, diferente do __.csv__ que armazena os dados como texto simples, o __.parquet__ usa compressão de coluna para reduzir significativamente o tamanho dos arquivos. Um exemplo próximo tópico.

# %% [markdown]
# ### Unindo os datasets
#
# Primeiro os datasets serão unidos no formato __.csv__.

# %%
# Bibliotecas que serão usadas para converter de .csv para .parquet

import pyarrow as pa
import pyarrow.parquet as pq

# %% [markdown]
# Concatenando os dataframes.

# %%
datasets = [df1, df2, df3, df4]

df_final = pd.concat(datasets)  # reúne os datasets df1, df2, df3, df4 em um só arquivo

# Salvando em um novo arquivo .csv

df_final.to_csv('notificacoes_sindrome_gripal_CE_2022.csv', sep = ',', index = False, encoding = 'utf-8')

# %% [markdown]
# ### Convertendo para .parquet

# %%
# Carregando o arquivo .csv em um novo dataframe

df_csv_to_parquet = pd.read_csv('notificacoes_sindrome_gripal_CE_2022.csv', sep=',', low_memory = False)

# Converte para uma tabela do PyArrow

tabela = pa.Table.from_pandas(df_csv_to_parquet)

# Salva no formato .parquet 

pq.write_table(tabela, 'notificacoes_sindrome_gripal_CE_2022.parquet')

# %% [markdown]
# O resultado foi um arquivo de aproximadamente 46MB comparados com os quase 422MB do arquivo __.csv__. Vamos dar uma breve conferida no novo arquivo.

# %%
# Abrindo um arquivo .parquet no Pandas

df_parquet = pd.read_parquet('notificacoes_sindrome_gripal_CE_2022.parquet')

# %%
# Verficando o shape

df_parquet.shape
# Out:
# (1309879, 64)

# %%
# Verificando as primeiras 50 linhas 

df_parquet.head(50)
# Out:
#                                              sintomas profissionalSaude  \
# 0                                       Febre, Coriza               Não
# 1   Coriza, Distúrbios Olfativos, Distúrbios Gusta...               Sim
# 2                              Tosse, Febre, Dispneia               Não
# 3                                Tosse, Dor de Cabeça               Não
# 4                               Coriza, Dor de Cabeça               Não
# 5                                Coriza, Febre, Tosse               Sim
# 6                                       Coriza, Tosse               Não
# 7   Coriza, Dor de Cabeça, Tosse, Febre, Dor de Ga...               Não
# 8               Coriza, Tosse, Febre, Dor de Garganta               Não
# 9                       Tosse, Febre, Dor de Garganta               Não
# 10                Dor de Cabeça, Tosse, Febre, Coriza               Não
# 11                Coriza, Dor de Cabeça, Febre, Tosse               Não
# 12                                      Assintomático               Não
# 13  Coriza, Dor de Cabeça, Tosse, Febre, Dor de Ga...               Não
# 14                                      Assintomático               Não
# 15                                      Tosse, Outros               Não
# 16                                       Tosse, Febre               Não
# 17                      Tosse, Febre, Dor de Garganta               Sim
# 18  Coriza, Tosse, Dispneia, Dor de Garganta, Dor ...               Não
# 19                                       Tosse, Febre               Não
# 20                               Tosse, Febre, Coriza               Não
# 21  Coriza, Dor de Cabeça, Tosse, Febre, Dor de Ga...               Não
# 22             Dor de Cabeça, Dor de Garganta, Outros               Não
# 23                                      Assintomático               Não
# 24  Distúrbios Gustativos, Dor de Cabeça, Tosse, F...               Sim
# 25                     Tosse, Dor de Garganta, Outros               Não
# 26      Coriza, Tosse, Febre, Dor de Garganta, Outros               Não
# 27                     Febre, Dor de Garganta, Outros               Não
# 28               Coriza, Dor de Cabeça, Tosse, Outros               Não
# 29  Coriza, Dor de Cabeça, Tosse, Febre, Dor de Ga...               Não
# 30       Dor de Cabeça, Tosse, Febre, Dor de Garganta               Não
# 31       Tosse, Febre, Dor de Garganta, Dor de Cabeça               Não
# 32                                      Febre, Outros               Não
# 33                                      Assintomático               Não
# 34                                      Assintomático               Não
# 35  Coriza, Dor de Cabeça, Tosse, Febre, Dor de Ga...               Não
# 36                                      Assintomático               Não
# 37                                      Assintomático               Não
# 38                             Tosse, Dor de Garganta               Não
# 39        Coriza, Dor de Cabeça, Tosse, Febre, Outros               Não
# 40                       Coriza, Dor de Cabeça, Tosse               Não
# 41                Coriza, Dor de Cabeça, Tosse, Febre               Não
# 42                        Dor de Cabeça, Tosse, Febre               Não
# 43                             Tosse, Febre, Dispneia               Não
# 44                               Tosse, Dor de Cabeça               Não
# 45                                           Dispneia               Não
# 46                               Coriza, Tosse, Febre               Não
# 47             Dor de Cabeça, Dor de Garganta, Coriza               Não
# 48              Coriza, Febre, Dor de Garganta, Tosse               Não
# 49                        Tosse, Febre, Dor de Cabeça               Não
#
#      racaCor                               outrosSintomas outrasCondicoes  \
# 0      Parda                                         None            None
# 1      Parda                                      MIALGIA            None
# 2      Parda                                         None            None
# 3      Parda                                         None            None
# 4      Parda                                         None            None
# 5   Ignorado                                         None             HAS
# 6      Parda                                         None            None
# 7      Parda                                     DIARREIA  DOENÇA CELÍACA
# 8      Parda                                         None            None
# 9      Parda                                         None            None
# 10     Parda                                         None            None
# 11  Ignorado                                         None             HAS
# 12     Parda                                         None            None
# 13     Preta                                         None            None
# 14     Parda                                         None            None
# 15     Parda  INFLUENZA A OU B, SUBTIPAGEM (H1N1 OU H3N2)            None
# 16  Ignorado                                         None            None
# 17     Parda                                         None            None
# 18    Branca                                         None             HAS
# 19  Ignorado                                         None            None
# 20     Parda                                         None            None
# 21   Amarela                                         None            None
# 22     Parda                              CONGESTÃO NASAL            None
# 23     Parda                                         None            None
# 24    Branca                                         None            None
# 25     Parda                    CONGESTÃO NASAL E MIALGIA            None
# 26     Parda                         TOSSE SECA E MIALGIA            None
# 27     Parda  INFLUENZA A OU B, SUBTIPAGEM (H1N1 OU H3N2)            None
# 28     Parda                                        GRIPE            None
# 29     Parda                                         None            None
# 30     Parda                                         None            None
# 31     Parda                                         None            None
# 32     Parda                                     DIARREIA            None
# 33     Parda                                         None            None
# 34     Parda                                         None            None
# 35  Ignorado                                         None            None
# 36     Parda                                         None            None
# 37     Parda                                         None            None
# 38   Amarela                                         None            None
# 39     Parda                                 dor no corpo            None
# 40     Parda                                         None            None
# 41     Parda                                         None            None
# 42  Ignorado                                         None            None
# 43    Branca                                         None            None
# 44     Parda                                         None            None
# 45     Parda                                         None            None
# 46  Ignorado                                         None            None
# 47     Parda                                         None            None
# 48  Ignorado                                         None            None
# 49     Parda                                         None            None
#
#    profissionalSeguranca                                         cbo  \
# 0                    Não                                        None
# 1                    Não                  2235 - Enfermeiros e afins
# 2                    Não                                        None
# 3                    Não                                        None
# 4                    Não                                        None
# 5                    Não  3222 - Técnicos e auxiliares de enfermagem
# 6                    Não                                        None
# 7                    Não                                        None
# 8                    Não                                        None
# 9                    Não                                        None
# 10                   Não                                        None
# 11                   Não  3222 - Técnicos e auxiliares de enfermagem
# 12                   Não                                        None
# 13                   Não              5241 - Vendedores em domicílio
# 14                   Não                                        None
# 15                   Não                                        None
# 16                   Não                                        None
# 17                   Não                                225 - Médico
# 18                   Não                                        None
# 19                   Não                                        None
# 20                   Não                                        None
# 21                   Não                                        None
# 22                   Não                                        None
# 23                   Não                                        None
# 24                  None    5199 - Outros trabalhadores dos serviços
# 25                   Não                                        None
# 26                   Não                                        None
# 27                   Não                                        None
# 28                   Não                                        None
# 29                   Não                                        None
# 30                   Não                                        None
# 31                   Não                                        None
# 32                   Não                                        None
# 33                   Não                                        None
# 34                   Não                                        None
# 35                   Não                                        None
# 36                   Não                                        None
# 37                   Não                                        None
# 38                   Não                                        None
# 39                   Não                                        None
# 40                   Não                                        None
# 41                   Não                                        None
# 42                   Não                                        None
# 43                   Não          0102 - Oficiais das forças armadas
# 44                   Não                                        None
# 45                   Não                                        None
# 46                   Não                                        None
# 47                   Não                                        None
# 48                   Não                                        None
# 49                   Não                                        None
#
#                                         condicoes       sexo estado  ...  \
# 0                                            None   Feminino  Ceará  ...
# 1                                            None   Feminino  Ceará  ...
# 2                                            None   Feminino  Ceará  ...
# 3                                            None   Feminino  Ceará  ...
# 4                                            None  Masculino  Ceará  ...
# 5                                          Outros   Feminino  Ceará  ...
# 6                                            None   Feminino  Ceará  ...
# 7                                          Outros   Feminino  Ceará  ...
# 8                                            None  Masculino  Ceará  ...
# 9   Doenças respiratórias crônicas descompensadas  Masculino  Ceará  ...
# 10                                           None   Feminino  Ceará  ...
# 11                                         Outros  Masculino  Ceará  ...
# 12  Doenças respiratórias crônicas descompensadas   Feminino  Ceará  ...
# 13                                Imunossupressão  Masculino  Ceará  ...
# 14                                           None   Feminino  Ceará  ...
# 15                                           None  Masculino  Ceará  ...
# 16                                           None   Feminino  Ceará  ...
# 17           Doenças cardíacas crônicas, Diabetes  Masculino  Ceará  ...
# 18             Doenças cardíacas crônicas, Outros  Masculino  Ceará  ...
# 19                                           None   Feminino  Ceará  ...
# 20                                           None  Masculino  Ceará  ...
# 21                                           None   Feminino  Ceará  ...
# 22                                           None   Feminino  Ceará  ...
# 23                                           None   Feminino  Ceará  ...
# 24  Doenças respiratórias crônicas descompensadas   Feminino  Ceará  ...
# 25  Doenças respiratórias crônicas descompensadas  Masculino  Ceará  ...
# 26                                           None   Feminino  Ceará  ...
# 27                                           None  Masculino  Ceará  ...
# 28                                           None   Feminino  Ceará  ...
# 29                                           None   Feminino  Ceará  ...
# 30                                           None  Masculino  Ceará  ...
# 31                                       Gestante   Feminino  Ceará  ...
# 32                                           None   Feminino  Ceará  ...
# 33                                           None   Feminino  Ceará  ...
# 34                                           None   Feminino  Ceará  ...
# 35                     Doenças cardíacas crônicas   Feminino  Ceará  ...
# 36                                           None   Feminino  Ceará  ...
# 37                                           None  Masculino  Ceará  ...
# 38                                           None  Masculino  Ceará  ...
# 39                                           None   Feminino  Ceará  ...
# 40                                           None  Masculino  Ceará  ...
# 41  Doenças respiratórias crônicas descompensadas   Feminino  Ceará  ...
# 42                                           None  Masculino  Ceará  ...
# 43                                           None  Masculino  Ceará  ...
# 44                                           None   Feminino  Ceará  ...
# 45                                           None   Feminino  Ceará  ...
# 46                                           None  Masculino  Ceará  ...
# 47                                           None   Feminino  Ceará  ...
# 48                                      Obesidade   Feminino  Ceará  ...
# 49                                           None  Masculino  Ceará  ...
#
#    codigoResultadoTeste3 codigoEstadoTeste4 codigoTipoTeste4  \
# 0                    NaN                NaN              NaN
# 1                    NaN                NaN              NaN
# 2                    NaN                NaN              NaN
# 3                    NaN                NaN              NaN
# 4                    NaN                NaN              NaN
# 5                    NaN                NaN              NaN
# 6                    NaN                NaN              NaN
# 7                    NaN                NaN              NaN
# 8                    NaN                NaN              NaN
# 9                    NaN                NaN              NaN
# 10                   NaN                NaN              NaN
# 11                   NaN                NaN              NaN
# 12                   NaN                NaN              NaN
# 13                   NaN                NaN              NaN
# 14                   NaN                NaN              NaN
# 15                   NaN                NaN              NaN
# 16                   NaN                NaN              NaN
# 17                   NaN                NaN              NaN
# 18                   NaN                NaN              NaN
# 19                   NaN                NaN              NaN
# 20                   NaN                NaN              NaN
# 21                   NaN                NaN              NaN
# 22                   NaN                NaN              NaN
# 23                   NaN                NaN              NaN
# 24                   NaN                NaN              NaN
# 25                   NaN                NaN              NaN
# 26                   NaN                NaN              NaN
# 27                   NaN                NaN              NaN
# 28                   NaN                NaN              NaN
# 29                   NaN                NaN              NaN
# 30                   NaN                NaN              NaN
# 31                   NaN                NaN              NaN
# 32                   NaN                NaN              NaN
# 33                   NaN                NaN              NaN
# 34                   NaN                NaN              NaN
# 35                   NaN                NaN              NaN
# 36                   NaN                NaN              NaN
# 37                   NaN                NaN              NaN
# 38                   NaN                NaN              NaN
# 39                   NaN                NaN              NaN
# 40                   NaN                NaN              NaN
# 41                   NaN                NaN              NaN
# 42                   NaN                NaN              NaN
# 43                   NaN                NaN              NaN
# 44                   NaN                NaN              NaN
# 45                   NaN                NaN              NaN
# 46                   NaN                NaN              NaN
# 47                   NaN                NaN              NaN
# 48                   NaN                NaN              NaN
# 49                   NaN                NaN              NaN
#
#    codigoFabricanteTeste4 codigoResultadoTeste4 dataColetaTeste1  \
# 0                     NaN                   NaN             None
# 1                     NaN                   NaN       2022-01-24
# 2                     NaN                   NaN       2022-08-16
# 3                     NaN                   NaN       2022-01-31
# 4                     NaN                   NaN       2022-07-06
# 5                     NaN                   NaN       2022-11-22
# 6                     NaN                   NaN       2022-06-27
# 7                     NaN                   NaN             None
# 8                     NaN                   NaN             None
# 9                     NaN                   NaN       2022-01-26
# 10                    NaN                   NaN             None
# 11                    NaN                   NaN       2022-01-22
# 12                    NaN                   NaN             None
# 13                    NaN                   NaN             None
# 14                    NaN                   NaN       2021-03-27
# 15                    NaN                   NaN       2022-04-02
# 16                    NaN                   NaN       2022-01-21
# 17                    NaN                   NaN       2022-01-21
# 18                    NaN                   NaN       2022-07-06
# 19                    NaN                   NaN       2022-07-19
# 20                    NaN                   NaN       2022-01-18
# 21                    NaN                   NaN             None
# 22                    NaN                   NaN             None
# 23                    NaN                   NaN       2021-03-31
# 24                    NaN                   NaN       2022-11-25
# 25                    NaN                   NaN       2022-07-09
# 26                    NaN                   NaN       2022-01-13
# 27                    NaN                   NaN       2022-02-09
# 28                    NaN                   NaN       2022-01-14
# 29                    NaN                   NaN       2022-01-25
# 30                    NaN                   NaN       2022-01-11
# 31                    NaN                   NaN             None
# 32                    NaN                   NaN       2021-12-22
# 33                    NaN                   NaN             None
# 34                    NaN                   NaN       2021-12-21
# 35                    NaN                   NaN             None
# 36                    NaN                   NaN       2022-07-05
# 37                    NaN                   NaN       2022-07-25
# 38                    NaN                   NaN       2022-11-23
# 39                    NaN                   NaN       2022-01-18
# 40                    NaN                   NaN       2022-01-11
# 41                    NaN                   NaN       2022-11-25
# 42                    NaN                   NaN       2022-01-25
# 43                    NaN                   NaN       2022-01-12
# 44                    NaN                   NaN       2022-06-27
# 45                    NaN                   NaN       2022-07-24
# 46                    NaN                   NaN       2022-04-28
# 47                    NaN                   NaN       2022-01-18
# 48                    NaN                   NaN             None
# 49                    NaN                   NaN       2022-02-14
#
#     dataColetaTeste2 dataColetaTeste3 dataColetaTeste4  idade
# 0               None             None             None    NaN
# 1               None             None             None   31.0
# 2               None             None             None   25.0
# 3               None             None             None   23.0
# 4               None             None             None    NaN
# 5               None             None             None    NaN
# 6               None             None             None    NaN
# 7               None             None             None   38.0
# 8               None             None             None   22.0
# 9               None             None             None   20.0
# 10              None             None             None   20.0
# 11        2022-01-22             None             None    NaN
# 12              None             None             None   43.0
# 13              None             None             None   28.0
# 14              None             None             None   33.0
# 15              None             None             None   44.0
# 16              None             None             None   29.0
# 17              None             None             None    NaN
# 18              None             None             None    NaN
# 19              None             None             None   24.0
# 20              None             None             None   30.0
# 21              None             None             None   25.0
# 22              None             None             None   29.0
# 23              None             None             None   46.0
# 24              None             None             None   45.0
# 25        2022-01-22             None             None   23.0
# 26              None             None             None   34.0
# 27              None             None             None   30.0
# 28              None             None             None   48.0
# 29              None             None             None    NaN
# 30              None             None             None   30.0
# 31              None             None             None   29.0
# 32              None             None             None    NaN
# 33              None             None             None   32.0
# 34              None             None             None    NaN
# 35              None             None             None    NaN
# 36              None             None             None   23.0
# 37              None             None             None    NaN
# 38              None             None             None   25.0
# 39              None             None             None    NaN
# 40              None             None             None   33.0
# 41              None             None             None   20.0
# 42              None             None             None   51.0
# 43              None             None             None   31.0
# 44              None             None             None   47.0
# 45              None             None             None    NaN
# 46              None             None             None   32.0
# 47              None             None             None   33.0
# 48              None             None             None   40.0
# 49              None             None             None   31.0
#
# [50 rows x 64 columns]

# %% [markdown]
# ### Conclusão
#
# Nessa primeira parte vimos algumas técnicas para lidar com conjunto de dados que ocupam muito espaço na memória, o que é comum de acontecer quando trabalhamos com dados armazenados em __.csv__, mesmo assim, arquivos grandes podem ser manipulados para que o consumo de memória pela biblioteca pandas seja reduzido, tornando a análise mais eficiente por economizar memória. A outra opção foi converter os arquivos em __.csv__ para __.parquet__. Em situações que envolvem um grande volume de dados trabalhar com o formato __.csv__ pode ser nada eficiente, para isso temos outras alternativas, como o formato __.parquet__, existe muita história por trás desse formato, nesse momento convém entender que ele possui uma forma muito melhor de comprimir as informações usando uma abordagem orientada as colunas.
